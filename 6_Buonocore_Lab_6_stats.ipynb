# %% [markdown]
# <a href="https://colab.research.google.com/github/billybuonocore/labs-4-10/blob/main/6_Buonocore_Lab_6_stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt # always use this for shortcuts

import pandas as pd
import urllib.request

# %%
url = "https://raw.githubusercontent.com/billybuonocore/Finance/main/cereal_data.csv"

# %%
urllib.request.urlretrieve(url,'cereal_data.csv')
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f3600915160>)

# %%
cereal_data = pd.read_csv('cereal_data.csv') # know this is data code

# %%
cereal_data # all nutrition facts about cereals
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_data['sugars']
# Out:
# 0      6
# 1      8
# 2      5
# 3      0
# 4      8
#       ..
# 72     3
# 73    12
# 74     3
# 75     3
# 76     8
# Name: sugars, Length: 77, dtype: int64

# %%
cereal_data[["calories", "sugars"]]
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
cereal_data[["calories", "sugars"]].mean()
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'_') # next few codes are each charts for sugars and calories of eacg cereal

# %%
x = cereal_data[["sugars"]]
y = cereal_data[["calories"]]

plt.plot(x,y,'.')
plt.xlabel("sugars")
plt.ylabel("calories")
plt.title("sugars vs calories")
# Out:
# Text(0.5, 1.0, 'sugars vs calories')

# %%
x = cereal_data[["fat"]]
y = cereal_data[["calories"]]
# cereals vs each others nutrition
plt.plot(x,y,'.')
plt.xlabel("fat")
plt.ylabel("calories")
plt.title("fat vs calories")
# Out:
# Text(0.5, 1.0, 'fat vs calories')

# %%
x = cereal_data[["sodium"]]
y = cereal_data[["weight"]]

plt.plot(x,y,'.')
plt.xlabel("sodium")
plt.ylabel("weight")
plt.title("sodium vs weight")
# Out:
# Text(0.5, 1.0, 'sodium vs weight')

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %%
x = cereal_data[["sodium"]]
y = cereal_data[["weight"]]

# %%
linear_regressor.fit(x,y)
y_pred = linear_regressor.predict(x)

# %%
plt.plot(x,y,'.')
plt.plot(x, y_pred, color='red')
plt.show()

# %%
x = np.linspace(0,10,50)

# %%
m = 3
b = 7
y = m * x + b

# %%
plt.plot(x,y,'.')

# %%
noise = 10 * np.random.randn(50,)

# %%
y = m * x + b + noise

# %%
plt.plot(x,y,'.')

# %%
m_guess = 5 #y=mx+b
b_guess = 15

y_guess = m_guess = x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
loss = np.sum((y_guess - y)**2)

# %%
for m_guess in np.linspace(-10,10,10):
  for b_guess in np.linspace(-10,10,10):

    y_guess = m_guess * x + b_guess
    plt.plot(x,y_guess,'r.');
    plt.plot(x,y,'g.');
    plt.show()

    loss = np.sum((y_guess - y)**2)

    print(loss,m_guess,b_guess)
# Out:
# 413160.5926871897 -10.0 -10.0
# 395077.36025888566 -10.0 -7.777777777777778
# 377487.95499107544 -10.0 -5.555555555555555
# 360392.3768837591 -10.0 -3.333333333333333
# 343790.62593693665 -10.0 -1.1111111111111107
# 327682.70215060795 -10.0 1.1111111111111107
# 312068.6055247731 -10.0 3.333333333333334
# 296948.33605943207 -10.0 5.555555555555557
# 282321.8937545849 -10.0 7.777777777777779
# 268189.27861023153 -10.0 10.0
# 305725.83930419205 -7.777777777777778 -10.0
# 290111.74267835723 -7.777777777777778 -7.777777777777778
# 274991.4732130161 -7.777777777777778 -5.555555555555555
# 260365.0309081689 -7.777777777777778 -3.333333333333333
# 246232.41576381552 -7.777777777777778 -1.1111111111111107
# 232593.62777995598 -7.777777777777778 1.1111111111111107
# 219448.66695659026 -7.777777777777778 3.333333333333334
# 206797.53329371836 -7.777777777777778 5.555555555555557
# 194640.22679134033 -7.777777777777778 7.777777777777779
# 182976.74744945602 -7.777777777777778 10.0
# ...

# %%
x = np.linspace(0,10,50)
m = 3
b = 7
y = m * x + b

# %%
best_loss = 10000000
best_m = 0
best_b = 0
for m_guess in np.linspace(-10,1000,50):
  for b_guess in np.linspace(-10,1000,50):

    y_guess = m_guess * x + b_guess
   
  loss = np.sum((y_guess - y)**2)

   if loss < best_loss:

     best_loss = loss
     best_m = m_guess
     best_b = b_guess
   
    plt.plot(x,y_guess,'r.');
    plt.plot(x,y,'g.');
    plt.show()

    
    print(loss,m_guess,b_guess)
# Out:
#   File "<tokenize>", line 17
#     plt.plot(x,y_guess,'r.');
#     ^
# IndentationError: unindent does not match any outer indentation level
